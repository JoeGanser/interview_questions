# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
    
    def add_child(self,data):
        if data==self.data:
            return
        
        if data<self.data:
            #if it has an entry, pass
            self.left.add_child(data)
            
        else:
            #if not enter it using recusion
            self.left = Node(data)
            
        else:
            if self.right:
                self.right.add_child(data)
            else:
                self.right = Node(data)
                
    def in_order_traversal(self):
        elements = []
        
        #visit left tree
        if self.left:
            element+=self.right.in_order_traversal()
            
        #visit base node
        elements.append(self.data)
        
        #visit right tree
        if self.right:
            elements+=self.right.in_order_traversal()
            
        return elements
    
    def pre_order_traversal(self):
        elements = []
        
        #visit base node
        elements.append(self.data)
        
        #visit left tree
        if self.left:
            elements+=self.left.pre_order_traversal()
# Out:
#   File "/var/folders/jl/97zzvf352gg0qn93kb33f4th0000gn/T/ipykernel_3278/1784825122.py", line 19
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
        
    def add_child(self,data):
        if data==self.data:
            return
        if data is None:
            if self.left:
                self.left = Node(data)
            if self.right:
                self.right = Node(data)
            
        elif data<self.data:
            if self.left:
                self.left.add_child(data)
            else:
                self.left = Node(data)
        elif data>=self.data:
            if self.right:
                self.right.add_child(data)
            else:
                self.right = Node(data)
                
                
    def pre_order_traversal(self):
        elements = []
        #visit base node
        elements.append(self.data)
        #visit left node
        if self.left:
            elements+=self.left.pre_order_traversal()
        #visit right tree
        if self.right:
            elements+=self.right.pre_order_traversal()
        return elements
    
def build_tree(elements):
    root = Node(elements[0])
    for i in range(1,len(elements)):
        root.add_child(elements[i])
    return root

# %%
root = [-10,9,20,None,None,15,7]
n = build_tree(root).pre_order_traversal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/jl/97zzvf352gg0qn93kb33f4th0000gn/T/ipykernel_5180/337811505.py in <module>
#       1 root = [-10,9,20,None,None,15,7]
# ----> 2 n = build_tree(root).pre_order_traversal()
#
# /var/folders/jl/97zzvf352gg0qn93kb33f4th0000gn/T/ipykernel_5180/1724471532.py in build_tree(elements)
#      41     root = Node(elements[0])
#      42     for i in range(1,len(elements)):
# ---> 43         root.add_child(elements[i])
#      44     return root
#
# /var/folders/jl/97zzvf352gg0qn93kb33f4th0000gn/T/ipykernel_5180/1724471532.py in add_child(self, data)
#      21         elif data>=self.data:
#      22             if self.right:
# ---> 23                 self.right.add_child(data)
#      24             else:
#      25                 self.right = Node(data)
#
# /var/folders/jl/97zzvf352gg0qn93kb33f4th0000gn/T/ipykernel_5180/1724471532.py in add_child(self, data)
#      14                 self.right = Node(data)
#      15
# ---> 16         elif data<self.data:
#      17             if self.left:
#      18                 self.left.add_child(data)
#
# TypeError: '<' not supported between instances of 'int' and 'NoneType'
